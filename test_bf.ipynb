# %%
import os
import glob
import pandas as pd
import numpy as np
import zipfile
from scipy.fft import fft, fftfreq
from scipy.signal import medfilt
import matplotlib.pyplot as plt

# ============================================================
# 設定與路徑
# ============================================================
base_path = r"E:\EarthScienceFair_Data"
target_folders = ["1", "2", "3", "4"] 
WINDOW_SIZE = 150
STRIDE = 5

# ============================================================
# 工具函式
# ============================================================

def clean_for_window(raw_data):
    s = pd.to_numeric(pd.Series(raw_data), errors='coerce')
    if s.isna().all(): return np.array([])
    s = s.interpolate(method='linear', limit_direction='both').ffill().bfill()
    val = s.values
    return val - np.mean(val) if len(val) > 0 else np.array([])


def get_sliding_freq(time, signal, win_size, stride):
    t_res, f_res = [], []
    for start in range(0, len(signal) - win_size, stride):
        end = start + win_size
        seg_t = time[start:end]
        seg_s = signal[start:end]

        N = len(seg_s)
        dt = np.mean(np.diff(seg_t))
        if dt <= 0: continue

        yf = fft(seg_s)
        xf = fftfreq(N, dt)[:N//2]
        amp = 2.0/N * np.abs(yf[:N//2])

        mask = (xf >= 1.2) & (xf <= 5.0)
        if np.any(mask) and np.sum(amp[mask]) > 0:
            f_main = np.sum(xf[mask] * amp[mask]) / np.sum(amp[mask])
            t_res.append(np.mean(seg_t))
            f_res.append(f_main)
    return np.array(t_res), np.array(f_res)

# ============================================================
# 主流程
# ============================================================
xlsx_files = []
for folder in target_folders:
    fp = os.path.join(base_path, folder)
    if os.path.exists(fp):
        found = glob.glob(os.path.join(fp, "**", "*.xlsx"), recursive=True)
        print(f"資料夾 {fp} 找到 {len(found)} 個 xlsx 檔案")
        xlsx_files.extend(found)
    else:
        print(f"資料夾不存在: {fp}")

for tracker_file in xlsx_files:
    file_id = os.path.splitext(os.path.basename(tracker_file))[0]
    print(f"\n處理中: {file_id}")

    try:
        ACC_THRESHOLD_CSV  = 0.4   # csv 用較高門檻（max=8.19，靜止約0.15）
        ACC_THRESHOLD_XLSX = 0.13  # xlsx ya 範圍 0.11~0.17，取中間偏高

        # ── 1. 先讀 xlsx ──────────────────────────────────────
        df = pd.read_excel(tracker_file, header=2)
        df_clean = df[pd.to_numeric(df['t_s'], errors='coerce').notna()].copy().reset_index(drop=True)
        print(f"  xlsx 有效行數: {len(df_clean)}/{len(df)} 筆")

        t_s_raw = pd.to_numeric(df_clean['t_s'], errors='coerce').values

        # xlsx 觸發點
        ya_abs = np.abs(pd.to_numeric(df_clean['ya'], errors='coerce').values)
        # 改用動態門檻：取中位數與最大值的中間點，或是最大值的 60%
        dynamic_thresh_xlsx = np.median(ya_abs) + (ya_abs.max() - np.median(ya_abs)) * 0.5
        trigger_xlsx = np.argmax(ya_abs > dynamic_thresh_xlsx)
        
            
        print(f"  xlsx 觸發點: index={trigger_xlsx}, t={t_s_raw[trigger_xlsx]:.4f}")
        print(f"  xlsx ya 絕對值: min={ya_abs.min():.4f}, max={ya_abs.max():.4f}, 中位數={np.median(ya_abs):.4f}")

        t_s = t_s_raw[trigger_xlsx:] - t_s_raw[trigger_xlsx]

        target_layers = {
            "ya": df_clean['ya'].values[trigger_xlsx:] if 'ya' in df_clean.columns else None,
            "yb": df_clean['yb'].values[trigger_xlsx:] if 'yb' in df_clean.columns else None,
            "yc": df_clean['yc'].values[trigger_xlsx:] if 'yc' in df_clean.columns else None,
            "yd": df_clean['yd'].values[trigger_xlsx:] if 'yd' in df_clean.columns else None,
            "ye": df_clean['ye'].values[trigger_xlsx:] if 'ye' in df_clean.columns else None
        }

        plt.figure(figsize=(12, 6))

        # ── 2. 再讀 csv ───────────────────────────────────────
        zip_path = os.path.join(os.path.dirname(tracker_file), f"{file_id}.zip")
        if os.path.exists(zip_path):
            with zipfile.ZipFile(zip_path, 'r') as z:
                csv_files = [f for f in z.namelist() if f.endswith('.csv')]
                if csv_files:
                    with z.open(csv_files[0]) as f:
                        acc_df = pd.read_csv(f)

                    # 先定義原始時間軸和觸發點
                    t_acc_raw = pd.to_numeric(acc_df.iloc[:, 0], errors='coerce').values
                    acc_abs = np.abs(pd.to_numeric(acc_df.iloc[:, -1], errors='coerce').values)
                    current_threshold = max(ACC_THRESHOLD_CSV, acc_abs.max() * 0.3)
                    trigger_acc = np.argmax(acc_abs > current_threshold)
                    consecutive_goal = 5
                    trigger_acc = 0
                    mask = acc_abs > current_threshold
                    for i in range(len(mask) - consecutive_goal):
                        if np.all(mask[i : i + consecutive_goal]):
                            trigger_acc = i
                            break
                        
                    print(f"  csv acc 絕對值: min={acc_abs.min():.4f}, max={acc_abs.max():.4f}, 中位數={np.median(acc_abs):.4f}")
                    print(f"  csv 觸發點: index={trigger_acc}, t={t_acc_raw[trigger_acc]:.4f}")

                    # 再裁切觸發點之後的資料
                    t_acc = t_acc_raw[trigger_acc:] - t_acc_raw[trigger_acc]
                    v_acc_raw = acc_df.iloc[:, -1].values[trigger_acc:]

                    # 最後裁切到 xlsx 時間範圍
                    t_max_xlsx = t_s[-1]
                    csv_mask = t_acc <= t_max_xlsx
                    t_acc = t_acc[csv_mask]
                    v_acc = clean_for_window(v_acc_raw[csv_mask])
                    print(f"  csv 裁切後: {len(t_acc)} 筆, 時間範圍 0 ~ {t_acc[-1]:.2f} s")

                    dt_acc  = np.median(np.diff(t_acc[t_acc > 0][:100])) if len(t_acc) > 10 else 0.01
                    dt_xlsx = np.median(np.diff(t_s[:100]))
                    win_acc    = max(int(WINDOW_SIZE * dt_xlsx / dt_acc), 30)
                    stride_acc = max(int(STRIDE     * dt_xlsx / dt_acc),  5)
                    t_p, f_p = get_sliding_freq(t_acc, v_acc, win_acc, stride_acc)
                    if len(t_p) > 0:
                        plt.plot(t_p, f_p, 'k--', label="Input (Accel-CSV)", alpha=0.8, linewidth=2)
                    print(f"  CSV: {len(t_acc)} 筆, win={win_acc}, stride={stride_acc}")
        else:
            print(f"  zip 不存在，略過 CSV")

        # ── 3. 畫 xlsx 層位 ───────────────────────────────────
        colors = {"ya": "red", "yb": "orange", "yc": "green", "yd": "blue", "ye":"cyan"}
        for name, raw_val in target_layers.items():
            if raw_val is None: continue
            clean_sig = clean_for_window(raw_val)
            if len(clean_sig) > WINDOW_SIZE:
                sig_med = medfilt(clean_sig, kernel_size=5)
                tp, fp = get_sliding_freq(t_s, sig_med, WINDOW_SIZE, STRIDE)
                if len(tp) > 0:
                    print(f"  層位 {name}: 頻率範圍 = {fp.min():.3f} ~ {fp.max():.3f} Hz")
                    plt.plot(tp, fp, color=colors[name], label=f"Layer {name}", alpha=0.7)

        plt.title(f"Sliding Window Analysis: {file_id}")
        plt.xlabel("Time (s)")
        plt.ylabel("Frequency (Hz)")
        plt.grid(True, alpha=0.3)
        plt.legend(loc='upper right')
        plt.tight_layout()
        plt.savefig(f"Sliding_{file_id}.png", dpi=150)
        plt.close()

        dt_acc  = np.median(np.diff(t_acc[:100]))
        dt_xlsx = np.median(np.diff(t_s[:100]))
        window_sec_acc  = win_acc * dt_acc
        window_sec_xlsx = WINDOW_SIZE * dt_xlsx

        print(f"  xlsx 觸發後: {len(t_s)} 筆, 時間範圍 0 ~ {t_s[-1]:.2f} s")
        print(f"  csv  觸發後: {len(t_acc)} 筆, 時間範圍 0 ~ {t_acc[-1]:.2f} s")
        print(f"  dt_xlsx={dt_xlsx:.4f}s, dt_acc={dt_acc:.4f}s")
        print(f"  xlsx 窗口={WINDOW_SIZE}點 = {window_sec_xlsx:.2f}s")
        print(f"  csv  窗口={win_acc}點 = {window_sec_acc:.2f}s")

    except Exception as e:
        print(f"失敗 {file_id}: {e}")
# Out:
# 資料夾 E:\EarthScienceFair_Data\1 找到 10 個 xlsx 檔案
# 資料夾 E:\EarthScienceFair_Data\2 找到 16 個 xlsx 檔案
# 資料夾 E:\EarthScienceFair_Data\3 找到 6 個 xlsx 檔案
# 資料夾 E:\EarthScienceFair_Data\4 找到 3 個 xlsx 檔案
#
# 處理中: 1-G2-1
#   xlsx 有效行數: 710/2411 筆
#   xlsx 觸發點: index=59, t=2.1333
#   xlsx ya 絕對值: min=0.0678, max=0.1978, 中位數=0.1457
#   csv acc 絕對值: min=0.0135, max=21.0661, 中位數=0.2862
#   csv 觸發點: index=1518, t=15.2343
#   csv 裁切後: 2157 筆, 時間範圍 0 ~ 21.63 s
#   CSV: 2157 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.680 ~ 3.191 Hz
#   層位 yb: 頻率範圍 = 1.691 ~ 3.416 Hz
#   層位 yc: 頻率範圍 = 1.697 ~ 3.569 Hz
#   層位 yd: 頻率範圍 = 1.676 ~ 3.604 Hz
#   層位 ye: 頻率範圍 = 1.863 ~ 3.605 Hz
#   xlsx 觸發後: 651 筆, 時間範圍 0 ~ 21.67 s
#   csv  觸發後: 2157 筆, 時間範圍 0 ~ 21.63 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G2-2
#   xlsx 有效行數: 711/2292 筆
#   xlsx 觸發點: index=54, t=1.9667
#   xlsx ya 絕對值: min=0.0678, max=0.1978, 中位數=0.1456
#   csv acc 絕對值: min=0.0123, max=21.8256, 中位數=0.0855
#   csv 觸發點: index=1995, t=20.0191
#   csv 裁切後: 2180 筆, 時間範圍 0 ~ 21.87 s
#   CSV: 2180 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.856 ~ 3.191 Hz
#   層位 yb: 頻率範圍 = 1.850 ~ 3.416 Hz
#   層位 yc: 頻率範圍 = 1.861 ~ 3.569 Hz
#   層位 yd: 頻率範圍 = 1.856 ~ 3.604 Hz
#   層位 ye: 頻率範圍 = 1.863 ~ 3.605 Hz
#   xlsx 觸發後: 657 筆, 時間範圍 0 ~ 21.87 s
#   csv  觸發後: 2180 筆, 時間範圍 0 ~ 21.87 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G2-3
#   xlsx 有效行數: 663/2331 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0287, max=21.1555, 中位數=0.5317
#   csv 觸發點: index=1248, t=12.5249
#   csv 裁切後: 2049 筆, 時間範圍 0 ~ 20.55 s
#   CSV: 2049 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.783 ~ 3.581 Hz
#   層位 yb: 頻率範圍 = 1.782 ~ 3.518 Hz
#   層位 yc: 頻率範圍 = 1.779 ~ 3.538 Hz
#   層位 yd: 頻率範圍 = 1.781 ~ 3.538 Hz
#   層位 ye: 頻率範圍 = 1.782 ~ 3.537 Hz
#   xlsx 觸發後: 663 筆, 時間範圍 0 ~ 22.07 s
#   csv  觸發後: 2049 筆, 時間範圍 0 ~ 20.55 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G2-4
#   xlsx 有效行數: 712/2505 筆
#   xlsx 觸發點: index=71, t=2.3667
#   xlsx ya 絕對值: min=0.4836, max=0.8768, 中位數=0.6595
#   csv acc 絕對值: min=0.0097, max=21.2882, 中位數=0.2798
#   csv 觸發點: index=1360, t=13.6492
#   csv 裁切後: 2127 筆, 時間範圍 0 ~ 21.33 s
#   CSV: 2127 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.698 ~ 3.608 Hz
#   層位 yb: 頻率範圍 = 1.702 ~ 3.611 Hz
#   層位 yc: 頻率範圍 = 1.696 ~ 3.594 Hz
#   層位 yd: 頻率範圍 = 1.696 ~ 3.593 Hz
#   層位 ye: 頻率範圍 = 1.694 ~ 3.599 Hz
#   xlsx 觸發後: 641 筆, 時間範圍 0 ~ 21.34 s
#   csv  觸發後: 2127 筆, 時間範圍 0 ~ 21.33 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G2-5
#   xlsx 有效行數: 689/2347 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0446, max=0.1320, 中位數=0.0852
#   csv acc 絕對值: min=0.0398, max=21.2604, 中位數=0.5317
#   csv 觸發點: index=1298, t=13.0256
#   csv 裁切後: 2146 筆, 時間範圍 0 ~ 21.52 s
#   CSV: 2146 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.890 ~ 3.628 Hz
#   層位 yb: 頻率範圍 = 1.892 ~ 3.568 Hz
#   層位 yc: 頻率範圍 = 1.885 ~ 3.619 Hz
#   層位 yd: 頻率範圍 = 1.894 ~ 3.620 Hz
#   層位 ye: 頻率範圍 = 1.897 ~ 3.625 Hz
#   xlsx 觸發後: 689 筆, 時間範圍 0 ~ 22.93 s
#   csv  觸發後: 2146 筆, 時間範圍 0 ~ 21.52 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-1
#   xlsx 有效行數: 749/2576 筆
#   xlsx 觸發點: index=51, t=1.7000
#   xlsx ya 絕對值: min=0.0906, max=0.1710, 中位數=0.1241
#   csv acc 絕對值: min=0.0157, max=21.3532, 中位數=0.8412
#   csv 觸發點: index=1320, t=13.2453
#   csv 裁切後: 2272 筆, 時間範圍 0 ~ 22.79 s
#   CSV: 2272 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.942 ~ 3.705 Hz
#   層位 yb: 頻率範圍 = 1.935 ~ 3.657 Hz
#   層位 yc: 頻率範圍 = 1.942 ~ 3.681 Hz
#   層位 yd: 頻率範圍 = 1.936 ~ 3.714 Hz
#   層位 ye: 頻率範圍 = 1.940 ~ 3.717 Hz
#   xlsx 觸發後: 698 筆, 時間範圍 0 ~ 23.23 s
#   csv  觸發後: 2272 筆, 時間範圍 0 ~ 22.79 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-2
#   xlsx 有效行數: 786/2518 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.2303, max=0.6370, 中位數=0.4510
#   csv acc 絕對值: min=0.0213, max=21.4873, 中位數=0.3923
#   csv 觸發點: index=1550, t=15.5549
#   csv 裁切後: 2163 筆, 時間範圍 0 ~ 21.69 s
#   CSV: 2163 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.766 ~ 3.572 Hz
#   層位 yb: 頻率範圍 = 1.754 ~ 3.573 Hz
#   層位 yc: 頻率範圍 = 1.753 ~ 3.582 Hz
#   層位 yd: 頻率範圍 = 1.754 ~ 3.604 Hz
#   層位 ye: 頻率範圍 = 1.762 ~ 3.614 Hz
#   xlsx 觸發後: 786 筆, 時間範圍 0 ~ 26.17 s
#   csv  觸發後: 2163 筆, 時間範圍 0 ~ 21.69 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-3
#   xlsx 有效行數: 718/2677 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0389, max=21.2176, 中位數=0.7189
#   csv 觸發點: index=1351, t=13.5564
#   csv 裁切後: 2158 筆, 時間範圍 0 ~ 21.64 s
#   CSV: 2158 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.855 ~ 3.650 Hz
#   層位 yb: 頻率範圍 = 1.855 ~ 3.646 Hz
#   層位 yc: 頻率範圍 = 1.853 ~ 3.667 Hz
#   層位 yd: 頻率範圍 = 1.852 ~ 3.670 Hz
#   層位 ye: 頻率範圍 = 1.852 ~ 3.662 Hz
#   xlsx 觸發後: 718 筆, 時間範圍 0 ~ 23.90 s
#   csv  觸發後: 2158 筆, 時間範圍 0 ~ 21.64 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-4
#   xlsx 有效行數: 744/2355 筆
#   xlsx 觸發點: index=61, t=2.0333
#   xlsx ya 絕對值: min=0.1025, max=0.1838, 中位數=0.1324
#   csv acc 絕對值: min=0.0086, max=21.1313, 中位數=0.8405
#   csv 觸發點: index=1159, t=11.6318
#   csv 裁切後: 2220 筆, 時間範圍 0 ~ 22.27 s
#   CSV: 2220 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.873 ~ 3.642 Hz
#   層位 yb: 頻率範圍 = 1.874 ~ 3.629 Hz
#   層位 yc: 頻率範圍 = 1.870 ~ 3.634 Hz
#   層位 yd: 頻率範圍 = 1.863 ~ 3.636 Hz
#   層位 ye: 頻率範圍 = 1.869 ~ 3.667 Hz
#   xlsx 觸發後: 683 筆, 時間範圍 0 ~ 22.73 s
#   csv  觸發後: 2220 筆, 時間範圍 0 ~ 22.27 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-5
#   xlsx 有效行數: 681/2396 筆
#   xlsx 觸發點: index=27, t=0.9000
#   xlsx ya 絕對值: min=0.0996, max=0.1791, 中位數=0.1357
#   csv acc 絕對值: min=0.0348, max=21.3678, 中位數=0.3534
#   csv 觸發點: index=1570, t=15.7528
#   csv 裁切後: 2103 筆, 時間範圍 0 ~ 21.09 s
#   CSV: 2103 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.767 ~ 3.597 Hz
#   層位 yb: 頻率範圍 = 1.776 ~ 3.574 Hz
#   層位 yc: 頻率範圍 = 1.767 ~ 3.584 Hz
#   層位 yd: 頻率範圍 = 1.766 ~ 3.582 Hz
#   層位 ye: 頻率範圍 = 1.772 ~ 3.591 Hz
#   xlsx 觸發後: 654 筆, 時間範圍 0 ~ 21.77 s
#   csv  觸發後: 2103 筆, 時間範圍 0 ~ 21.09 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-1
#   xlsx 有效行數: 757/2773 筆
#   xlsx 觸發點: index=310, t=10.3333
#   xlsx ya 絕對值: min=0.0761, max=0.1957, 中位數=0.1182
#   csv acc 絕對值: min=0.0468, max=20.8883, 中位數=0.4662
#   csv 觸發點: index=1629, t=16.3612
#   csv 裁切後: 1482 筆, 時間範圍 0 ~ 14.86 s
#   CSV: 1482 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.912 ~ 3.625 Hz
#   層位 yb: 頻率範圍 = 1.898 ~ 3.623 Hz
#   層位 yc: 頻率範圍 = 1.892 ~ 3.628 Hz
#   層位 yd: 頻率範圍 = 1.899 ~ 3.633 Hz
#   層位 ye: 頻率範圍 = 1.899 ~ 3.651 Hz
#   xlsx 觸發後: 447 筆, 時間範圍 0 ~ 14.87 s
#   csv  觸發後: 1482 筆, 時間範圍 0 ~ 14.86 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-2
#   xlsx 有效行數: 747/2699 筆
#   xlsx 觸發點: index=266, t=8.8667
#   xlsx ya 絕對值: min=0.0455, max=0.1707, 中位數=0.0820
#   csv acc 絕對值: min=0.0346, max=20.6518, 中位數=0.9420
#   csv 觸發點: index=1166, t=11.7081
#   csv 裁切後: 1595 筆, 時間範圍 0 ~ 16.00 s
#   CSV: 1595 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.661 ~ 3.682 Hz
#   層位 yb: 頻率範圍 = 1.656 ~ 3.663 Hz
#   層位 yc: 頻率範圍 = 1.641 ~ 3.680 Hz
#   層位 yd: 頻率範圍 = 1.653 ~ 3.678 Hz
#   層位 ye: 頻率範圍 = 1.660 ~ 3.697 Hz
#   xlsx 觸發後: 481 筆, 時間範圍 0 ~ 16.00 s
#   csv  觸發後: 1595 筆, 時間範圍 0 ~ 16.00 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-3
#   xlsx 有效行數: 668/2333 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0230, max=20.8028, 中位數=0.6852
#   csv 觸發點: index=1152, t=11.5620
#   csv 裁切後: 2062 筆, 時間範圍 0 ~ 20.68 s
#   CSV: 2062 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.928 ~ 3.584 Hz
#   層位 yb: 頻率範圍 = 1.928 ~ 3.592 Hz
#   層位 yc: 頻率範圍 = 1.921 ~ 3.588 Hz
#   層位 yd: 頻率範圍 = 1.903 ~ 3.589 Hz
#   層位 ye: 頻率範圍 = 1.924 ~ 3.589 Hz
#   xlsx 觸發後: 668 筆, 時間範圍 0 ~ 22.23 s
#   csv  觸發後: 2062 筆, 時間範圍 0 ~ 20.68 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-4
#   xlsx 有效行數: 738/2460 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0316, max=20.8141, 中位數=0.6934
#   csv 觸發點: index=1311, t=13.1565
#   csv 裁切後: 2258 筆, 時間範圍 0 ~ 22.65 s
#   CSV: 2258 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.705 ~ 3.685 Hz
#   層位 yb: 頻率範圍 = 1.755 ~ 3.685 Hz
#   層位 yc: 頻率範圍 = 1.757 ~ 3.701 Hz
#   層位 yd: 頻率範圍 = 1.706 ~ 3.721 Hz
#   層位 ye: 頻率範圍 = 1.751 ~ 3.743 Hz
#   xlsx 觸發後: 738 筆, 時間範圍 0 ~ 24.57 s
#   csv  觸發後: 2258 筆, 時間範圍 0 ~ 22.65 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-5
#   xlsx 有效行數: 718/2510 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0288, max=20.7179, 中位數=0.4382
#   csv 觸發點: index=1414, t=14.1938
#   csv 裁切後: 2317 筆, 時間範圍 0 ~ 23.24 s
#   CSV: 2317 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.698 ~ 3.615 Hz
#   層位 yb: 頻率範圍 = 1.705 ~ 3.648 Hz
#   層位 yc: 頻率範圍 = 1.707 ~ 3.537 Hz
#   層位 yd: 頻率範圍 = 1.701 ~ 3.691 Hz
#   層位 ye: 頻率範圍 = 1.698 ~ 3.703 Hz
#   xlsx 觸發後: 718 筆, 時間範圍 0 ~ 23.90 s
#   csv  觸發後: 2317 筆, 時間範圍 0 ~ 23.24 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G2-1
#   xlsx 有效行數: 557/2049 筆
#   xlsx 觸發點: index=39, t=1.3000
#   xlsx ya 絕對值: min=0.0983, max=0.1733, 中位數=0.1308
#   csv acc 絕對值: min=0.0334, max=11.4331, 中位數=0.2729
#   csv 觸發點: index=1023, t=10.2676
#   csv 裁切後: 1718 筆, 時間範圍 0 ~ 17.23 s
#   CSV: 1718 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.985 ~ 2.881 Hz
#   層位 yb: 頻率範圍 = 1.979 ~ 2.881 Hz
#   層位 yc: 頻率範圍 = 1.976 ~ 2.875 Hz
#   層位 yd: 頻率範圍 = 1.975 ~ 2.876 Hz
#   層位 ye: 頻率範圍 = 1.973 ~ 2.878 Hz
#   xlsx 觸發後: 518 筆, 時間範圍 0 ~ 17.23 s
#   csv  觸發後: 1718 筆, 時間範圍 0 ~ 17.23 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G2-2
#   xlsx 有效行數: 522/1839 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0299, max=11.6232, 中位數=0.2373
#   csv 觸發點: index=1150, t=11.5404
#   csv 裁切後: 1731 筆, 時間範圍 0 ~ 17.36 s
#   CSV: 1731 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.801 ~ 2.798 Hz
#   層位 yb: 頻率範圍 = 1.800 ~ 2.797 Hz
#   層位 yc: 頻率範圍 = 1.790 ~ 2.796 Hz
#   層位 yd: 頻率範圍 = 1.794 ~ 2.792 Hz
#   層位 ye: 頻率範圍 = 1.792 ~ 2.795 Hz
#   xlsx 觸發後: 522 筆, 時間範圍 0 ~ 17.37 s
#   csv  觸發後: 1731 筆, 時間範圍 0 ~ 17.36 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G2-3
#   xlsx 有效行數: 579/2016 筆
#   xlsx 觸發點: index=59, t=1.9667
#   xlsx ya 絕對值: min=0.0913, max=0.1676, 中位數=0.1222
#   csv acc 絕對值: min=0.0395, max=11.2750, 中位數=0.1963
#   csv 觸發點: index=1213, t=12.1695
#   csv 裁切後: 1725 筆, 時間範圍 0 ~ 17.30 s
#   CSV: 1725 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.836 ~ 2.871 Hz
#   層位 yb: 頻率範圍 = 1.835 ~ 2.867 Hz
#   層位 yc: 頻率範圍 = 1.830 ~ 2.866 Hz
#   層位 yd: 頻率範圍 = 1.832 ~ 2.867 Hz
#   層位 ye: 頻率範圍 = 1.827 ~ 2.869 Hz
#   xlsx 觸發後: 520 筆, 時間範圍 0 ~ 17.30 s
#   csv  觸發後: 1725 筆, 時間範圍 0 ~ 17.30 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G3-1
#   xlsx 有效行數: 654/2218 筆
#   xlsx 觸發點: index=35, t=1.1667
#   xlsx ya 絕對值: min=0.0754, max=0.1585, 中位數=0.1158
#   csv acc 絕對值: min=0.0262, max=13.5200, 中位數=0.4512
#   csv 觸發點: index=1223, t=12.2764
#   csv 裁切後: 2026 筆, 時間範圍 0 ~ 20.32 s
#   CSV: 2026 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.737 ~ 3.048 Hz
#   層位 yb: 頻率範圍 = 1.729 ~ 3.048 Hz
#   層位 yc: 頻率範圍 = 1.723 ~ 3.043 Hz
#   層位 yd: 頻率範圍 = 1.720 ~ 3.028 Hz
#   層位 ye: 頻率範圍 = 1.723 ~ 3.017 Hz
#   xlsx 觸發後: 619 筆, 時間範圍 0 ~ 20.60 s
#   csv  觸發後: 2026 筆, 時間範圍 0 ~ 20.32 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G3-2
#   xlsx 有效行數: 343/1410 筆
#   xlsx 觸發點: index=23, t=0.7667
#   xlsx ya 絕對值: min=0.0538, max=0.1374, 中位數=0.0964
#   csv acc 絕對值: min=0.0290, max=13.9887, 中位數=0.3758
#   csv 觸發點: index=1085, t=10.8878
#   csv 裁切後: 1060 筆, 時間範圍 0 ~ 10.63 s
#   CSV: 1060 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.997 ~ 3.053 Hz
#   層位 yb: 頻率範圍 = 1.992 ~ 3.017 Hz
#   層位 yc: 頻率範圍 = 2.006 ~ 2.984 Hz
#   層位 yd: 頻率範圍 = 1.980 ~ 3.017 Hz
#   層位 ye: 頻率範圍 = 1.980 ~ 3.009 Hz
#   xlsx 觸發後: 320 筆, 時間範圍 0 ~ 10.63 s
#   csv  觸發後: 1060 筆, 時間範圍 0 ~ 10.63 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G3-3
#   xlsx 有效行數: 621/622 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0435, max=0.1249, 中位數=0.0843
#   csv acc 絕對值: min=0.0400, max=13.3901, 中位數=0.5864
#   csv 觸發點: index=1172, t=11.7645
#   csv 裁切後: 1886 筆, 時間範圍 0 ~ 18.92 s
#   CSV: 1886 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.893 ~ 3.043 Hz
#   層位 yb: 頻率範圍 = 1.890 ~ 3.046 Hz
#   層位 yc: 頻率範圍 = 1.881 ~ 3.059 Hz
#   層位 yd: 頻率範圍 = 1.882 ~ 3.052 Hz
#   層位 ye: 頻率範圍 = 1.879 ~ 3.056 Hz
#   xlsx 觸發後: 621 筆, 時間範圍 0 ~ 20.67 s
#   csv  觸發後: 1886 筆, 時間範圍 0 ~ 18.92 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G4-1
#   xlsx 有效行數: 233/961 筆
#   xlsx 觸發點: index=44, t=1.4667
#   xlsx ya 絕對值: min=0.0883, max=0.1627, 中位數=0.1115
#   csv acc 絕對值: min=0.0393, max=21.3812, 中位數=0.3046
#   csv 觸發點: index=1146, t=11.5005
#   csv 裁切後: 625 筆, 時間範圍 0 ~ 6.26 s
#   CSV: 625 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 2.153 ~ 2.456 Hz
#   層位 yb: 頻率範圍 = 2.155 ~ 2.446 Hz
#   層位 yc: 頻率範圍 = 2.157 ~ 2.441 Hz
#   層位 yd: 頻率範圍 = 2.152 ~ 2.434 Hz
#   層位 ye: 頻率範圍 = 2.151 ~ 2.421 Hz
#   xlsx 觸發後: 189 筆, 時間範圍 0 ~ 6.27 s
#   csv  觸發後: 625 筆, 時間範圍 0 ~ 6.26 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G4-2
# 失敗 2-G4-2: 't_s'
#
# 處理中: 2-G4-3
#   xlsx 有效行數: 278/869 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0414, max=0.1238, 中位數=0.0839
#   csv acc 絕對值: min=0.0286, max=21.4542, 中位數=0.3415
#   csv 觸發點: index=1385, t=13.8987
#   csv 裁切後: 921 筆, 時間範圍 0 ~ 9.23 s
#   CSV: 921 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.885 ~ 2.797 Hz
#   層位 yb: 頻率範圍 = 1.871 ~ 2.776 Hz
#   層位 yc: 頻率範圍 = 1.883 ~ 2.767 Hz
#   層位 yd: 頻率範圍 = 1.882 ~ 2.764 Hz
#   層位 ye: 頻率範圍 = 1.892 ~ 2.764 Hz
#   xlsx 觸發後: 278 筆, 時間範圍 0 ~ 9.23 s
#   csv  觸發後: 921 筆, 時間範圍 0 ~ 9.23 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G5-1
#   xlsx 有效行數: 302/1179 筆
#   xlsx 觸發點: index=42, t=1.4000
#   xlsx ya 絕對值: min=0.0984, max=0.1842, 中位數=0.1343
#   csv acc 絕對值: min=0.0327, max=17.3296, 中位數=1.0479
#   csv 觸發點: index=1307, t=13.1166
#   csv 裁切後: 861 筆, 時間範圍 0 ~ 8.63 s
#   CSV: 861 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.985 ~ 2.779 Hz
#   層位 yb: 頻率範圍 = 1.980 ~ 2.769 Hz
#   層位 yc: 頻率範圍 = 2.109 ~ 2.837 Hz
#   層位 yd: 頻率範圍 = 1.977 ~ 2.764 Hz
#   層位 ye: 頻率範圍 = 1.971 ~ 2.771 Hz
#   xlsx 觸發後: 260 筆, 時間範圍 0 ~ 8.63 s
#   csv  觸發後: 861 筆, 時間範圍 0 ~ 8.63 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G5-2
#   xlsx 有效行數: 239/1012 筆
#   xlsx 觸發點: index=19, t=0.6333
#   xlsx ya 絕對值: min=0.0933, max=0.1819, 中位數=0.1368
#   csv acc 絕對值: min=0.0128, max=15.9136, 中位數=0.3173
#   csv 觸發點: index=1421, t=14.2630
#   csv 裁切後: 728 筆, 時間範圍 0 ~ 7.30 s
#   CSV: 728 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 2.073 ~ 2.633 Hz
#   層位 yb: 頻率範圍 = 2.066 ~ 2.622 Hz
#   層位 yc: 頻率範圍 = 2.062 ~ 2.610 Hz
#   層位 yd: 頻率範圍 = 2.054 ~ 2.597 Hz
#   層位 ye: 頻率範圍 = 2.046 ~ 2.584 Hz
#   xlsx 觸發後: 220 筆, 時間範圍 0 ~ 7.30 s
#   csv  觸發後: 728 筆, 時間範圍 0 ~ 7.30 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G1-1
#   xlsx 有效行數: 682/2219 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0219, max=20.9714, 中位數=0.2637
#   csv 觸發點: index=1676, t=16.8194
#   csv 裁切後: 2107 筆, 時間範圍 0 ~ 21.13 s
#   CSV: 2107 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.689 ~ 3.581 Hz
#   層位 yb: 頻率範圍 = 1.672 ~ 3.286 Hz
#   層位 yc: 頻率範圍 = 1.672 ~ 3.593 Hz
#   層位 yd: 頻率範圍 = 1.672 ~ 3.592 Hz
#   層位 ye: 頻率範圍 = 1.665 ~ 3.618 Hz
#   xlsx 觸發後: 682 筆, 時間範圍 0 ~ 22.70 s
#   csv  觸發後: 2107 筆, 時間範圍 0 ~ 21.13 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G1-2
#   xlsx 有效行數: 671/1364 筆
#   xlsx 觸發點: index=49, t=1.6333
#   xlsx ya 絕對值: min=0.1041, max=0.1908, 中位數=0.1374
#   csv acc 絕對值: min=0.0263, max=20.9491, 中位數=0.2682
#   csv 觸發點: index=1442, t=14.4684
#   csv 裁切後: 2063 筆, 時間範圍 0 ~ 20.69 s
#   CSV: 2063 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.795 ~ 3.475 Hz
#   層位 yb: 頻率範圍 = 1.787 ~ 3.356 Hz
#   層位 yc: 頻率範圍 = 1.799 ~ 3.449 Hz
#   層位 yd: 頻率範圍 = 1.773 ~ 3.454 Hz
#   層位 ye: 頻率範圍 = 1.800 ~ 3.459 Hz
#   xlsx 觸發後: 622 筆, 時間範圍 0 ~ 20.70 s
#   csv  觸發後: 2063 筆, 時間範圍 0 ~ 20.69 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G1-3
#   xlsx 有效行數: 622/622 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0312, max=21.1846, 中位數=0.4647
#   csv 觸發點: index=1438, t=14.4315
#   csv 裁切後: 2063 筆, 時間範圍 0 ~ 20.69 s
#   CSV: 2063 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.893 ~ 3.043 Hz
#   層位 yb: 頻率範圍 = 1.890 ~ 3.046 Hz
#   層位 yc: 頻率範圍 = 1.881 ~ 3.059 Hz
#   層位 yd: 頻率範圍 = 1.882 ~ 3.052 Hz
#   層位 ye: 頻率範圍 = 1.879 ~ 3.056 Hz
#   xlsx 觸發後: 622 筆, 時間範圍 0 ~ 20.70 s
#   csv  觸發後: 2063 筆, 時間範圍 0 ~ 20.69 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G2-1
#   xlsx 有效行數: 605/2218 筆
#   xlsx 觸發點: index=35, t=1.1667
#   xlsx ya 絕對值: min=0.0706, max=0.1416, 中位數=0.1101
#   csv acc 絕對值: min=0.0367, max=13.0846, 中位數=0.2583
#   csv 觸發點: index=1100, t=11.0383
#   csv 裁切後: 1891 筆, 時間範圍 0 ~ 18.97 s
#   CSV: 1891 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.854 ~ 3.088 Hz
#   層位 yb: 頻率範圍 = 1.860 ~ 3.091 Hz
#   層位 yc: 頻率範圍 = 1.860 ~ 3.090 Hz
#   層位 yd: 頻率範圍 = 1.856 ~ 3.093 Hz
#   層位 ye: 頻率範圍 = 1.852 ~ 3.086 Hz
#   xlsx 觸發後: 570 筆, 時間範圍 0 ~ 18.97 s
#   csv  觸發後: 1891 筆, 時間範圍 0 ~ 18.97 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G2-2
#   xlsx 有效行數: 612/1375 筆
#   xlsx 觸發點: index=67, t=2.2333
#   xlsx ya 絕對值: min=0.0667, max=0.1369, 中位數=0.1033
#   csv acc 絕對值: min=0.0262, max=13.0446, 中位數=0.2982
#   csv 觸發點: index=1228, t=12.3239
#   csv 裁切後: 1808 筆, 時間範圍 0 ~ 18.13 s
#   CSV: 1808 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.938 ~ 3.071 Hz
#   層位 yb: 頻率範圍 = 1.934 ~ 3.066 Hz
#   層位 yc: 頻率範圍 = 1.929 ~ 3.067 Hz
#   層位 yd: 頻率範圍 = 1.936 ~ 3.075 Hz
#   層位 ye: 頻率範圍 = 1.936 ~ 3.073 Hz
#   xlsx 觸發後: 545 筆, 時間範圍 0 ~ 18.13 s
#   csv  觸發後: 1808 筆, 時間範圍 0 ~ 18.13 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G2-3
#   xlsx 有效行數: 622/622 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0435, max=0.1249, 中位數=0.0844
#   csv acc 絕對值: min=0.0437, max=13.1936, 中位數=0.2099
#   csv 觸發點: index=1255, t=12.5948
#   csv 裁切後: 2042 筆, 時間範圍 0 ~ 20.48 s
#   CSV: 2042 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.893 ~ 3.043 Hz
#   層位 yb: 頻率範圍 = 1.890 ~ 3.046 Hz
#   層位 yc: 頻率範圍 = 1.881 ~ 3.059 Hz
#   層位 yd: 頻率範圍 = 1.882 ~ 3.052 Hz
#   層位 ye: 頻率範圍 = 1.879 ~ 3.056 Hz
#   xlsx 觸發後: 622 筆, 時間範圍 0 ~ 20.70 s
#   csv  觸發後: 2042 筆, 時間範圍 0 ~ 20.48 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 4-G1-1
#   xlsx 有效行數: 775/2508 筆
#   xlsx 觸發點: index=41, t=1.3667
#   xlsx ya 絕對值: min=0.0682, max=0.1370, 中位數=0.1027
#   csv acc 絕對值: min=0.0355, max=21.4478, 中位數=0.6284
#   csv 觸發點: index=1465, t=14.7185
#   csv 裁切後: 2435 筆, 時間範圍 0 ~ 24.43 s
#   CSV: 2435 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.775 ~ 3.768 Hz
#   層位 yb: 頻率範圍 = 1.776 ~ 3.761 Hz
#   層位 yc: 頻率範圍 = 1.773 ~ 3.757 Hz
#   層位 yd: 頻率範圍 = 1.772 ~ 3.771 Hz
#   層位 ye: 頻率範圍 = 1.769 ~ 3.768 Hz
#   xlsx 觸發後: 734 筆, 時間範圍 0 ~ 24.44 s
#   csv  觸發後: 2435 筆, 時間範圍 0 ~ 24.43 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 4-G1-2
#   xlsx 有效行數: 681/2364 筆
#   xlsx 觸發點: index=40, t=1.3333
#   xlsx ya 絕對值: min=0.0508, max=0.1207, 中位數=0.0817
#   csv acc 絕對值: min=0.0178, max=21.7388, 中位數=0.3794
#   csv 觸發點: index=1514, t=15.1935
#   csv 裁切後: 2096 筆, 時間範圍 0 ~ 21.02 s
#   CSV: 2096 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.783 ~ 3.614 Hz
#   層位 yb: 頻率範圍 = 1.784 ~ 3.614 Hz
#   層位 yc: 頻率範圍 = 1.779 ~ 3.619 Hz
#   層位 yd: 頻率範圍 = 1.779 ~ 3.609 Hz
#   層位 ye: 頻率範圍 = 1.779 ~ 3.610 Hz
#   xlsx 觸發後: 641 筆, 時間範圍 0 ~ 21.33 s
#   csv  觸發後: 2096 筆, 時間範圍 0 ~ 21.02 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 4-G1-3
#   xlsx 有效行數: 776/2684 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0189, max=21.5910, 中位數=0.7038
#   csv 觸發點: index=1396, t=14.0117
#   csv 裁切後: 2391 筆, 時間範圍 0 ~ 23.99 s
#   CSV: 2391 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.731 ~ 3.740 Hz
#   層位 yb: 頻率範圍 = 1.727 ~ 3.737 Hz
#   層位 yc: 頻率範圍 = 1.723 ~ 3.739 Hz
#   層位 yd: 頻率範圍 = 1.718 ~ 3.740 Hz
#   層位 ye: 頻率範圍 = 1.731 ~ 3.728 Hz
#   xlsx 觸發後: 776 筆, 時間範圍 0 ~ 25.84 s
#   csv  觸發後: 2391 筆, 時間範圍 0 ~ 23.99 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s

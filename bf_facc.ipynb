# %%
import os
import glob
import pandas as pd
import numpy as np
import zipfile
from scipy.fft import fft, fftfreq
from scipy.signal import medfilt
import matplotlib.pyplot as plt

# ============================================================
# 設定與路徑
# ============================================================
base_path = r"E:\EarthScienceFair_Data"
target_folders = ["1", "2", "3", "4"] 
WINDOW_SIZE = 150
STRIDE = 5

# ============================================================
# 工具函式
# ============================================================

def clean_for_window(raw_data):
    s = pd.to_numeric(pd.Series(raw_data), errors='coerce')
    if s.isna().all(): return np.array([])
    s = s.interpolate(method='linear', limit_direction='both').ffill().bfill()
    val = s.values
    return val - np.mean(val) if len(val) > 0 else np.array([])


def get_sliding_freq(time, signal, win_size, stride):
    t_res, f_res = [], []
    for start in range(0, len(signal) - win_size, stride):
        end = start + win_size
        seg_t = time[start:end]
        seg_s = signal[start:end]

        N = len(seg_s)
        dt = np.mean(np.diff(seg_t))
        if dt <= 0: continue

        yf = fft(seg_s)
        xf = fftfreq(N, dt)[:N//2]
        amp = 2.0/N * np.abs(yf[:N//2])

        mask = (xf >= 1.2) & (xf <= 5.0)
        if np.any(mask) and np.sum(amp[mask]) > 0:
            f_main = np.sum(xf[mask] * amp[mask]) / np.sum(amp[mask])
            t_res.append(np.mean(seg_t))
            f_res.append(f_main)
    return np.array(t_res), np.array(f_res)

# ============================================================
# 主流程
# ============================================================
xlsx_files = []
for folder in target_folders:
    fp = os.path.join(base_path, folder)
    if os.path.exists(fp):
        found = glob.glob(os.path.join(fp, "**", "*.xlsx"), recursive=True)
        print(f"資料夾 {fp} 找到 {len(found)} 個 xlsx 檔案")
        xlsx_files.extend(found)
    else:
        print(f"資料夾不存在: {fp}")

for tracker_file in xlsx_files:
    file_id = os.path.splitext(os.path.basename(tracker_file))[0]
    print(f"\n處理中: {file_id}")

    try:
        ACC_THRESHOLD_CSV  = 0.5   # csv 用較高門檻（max=8.19，靜止約0.15）
        ACC_THRESHOLD_XLSX = 0.14  # xlsx ya 範圍 0.11~0.17，取中間偏高

        # ── 1. 先讀 xlsx ──────────────────────────────────────
        df = pd.read_excel(tracker_file, header=2)
        df_clean = df[pd.to_numeric(df['t_s'], errors='coerce').notna()].copy().reset_index(drop=True)
        print(f"  xlsx 有效行數: {len(df_clean)}/{len(df)} 筆")

        t_s_raw = pd.to_numeric(df_clean['t_s'], errors='coerce').values

        # xlsx 觸發點
        ya_abs = np.abs(pd.to_numeric(df_clean['ya'], errors='coerce').values)
        trigger_xlsx = np.argmax(ya_abs > ACC_THRESHOLD_XLSX)
        print(f"  xlsx 觸發點: index={trigger_xlsx}, t={t_s_raw[trigger_xlsx]:.4f}")
        print(f"  xlsx ya 絕對值: min={ya_abs.min():.4f}, max={ya_abs.max():.4f}, 中位數={np.median(ya_abs):.4f}")

        t_s = t_s_raw[trigger_xlsx:] - t_s_raw[trigger_xlsx]

        target_layers = {
            "ya": df_clean['ya'].values[trigger_xlsx:] if 'ya' in df_clean.columns else None,
            "yb": df_clean['yb'].values[trigger_xlsx:] if 'yb' in df_clean.columns else None,
            "yc": df_clean['yc'].values[trigger_xlsx:] if 'yc' in df_clean.columns else None,
            "yd": df_clean['yd'].values[trigger_xlsx:] if 'yd' in df_clean.columns else None,
            "ye": df_clean['ye'].values[trigger_xlsx:] if 'ye' in df_clean.columns else None
        }

        plt.figure(figsize=(12, 6))

        # ── 2. 再讀 csv ───────────────────────────────────────
        zip_path = os.path.join(os.path.dirname(tracker_file), f"{file_id}.zip")
        if os.path.exists(zip_path):
            with zipfile.ZipFile(zip_path, 'r') as z:
                csv_files = [f for f in z.namelist() if f.endswith('.csv')]
                if csv_files:
                    with z.open(csv_files[0]) as f:
                        acc_df = pd.read_csv(f)

                    # 先定義原始時間軸和觸發點
                    t_acc_raw = pd.to_numeric(acc_df.iloc[:, 0], errors='coerce').values
                    acc_abs = np.abs(pd.to_numeric(acc_df.iloc[:, -1], errors='coerce').values)
                    print(f"  csv acc 絕對值: min={acc_abs.min():.4f}, max={acc_abs.max():.4f}, 中位數={np.median(acc_abs):.4f}")

                    trigger_acc = np.argmax(acc_abs > ACC_THRESHOLD_CSV)
                    print(f"  csv 觸發點: index={trigger_acc}, t={t_acc_raw[trigger_acc]:.4f}")

                    # 再裁切觸發點之後的資料
                    t_acc = t_acc_raw[trigger_acc:] - t_acc_raw[trigger_acc]
                    v_acc_raw = acc_df.iloc[:, -1].values[trigger_acc:]

                    # 最後裁切到 xlsx 時間範圍
                    t_max_xlsx = t_s[-1]
                    csv_mask = t_acc <= t_max_xlsx
                    t_acc = t_acc[csv_mask]
                    v_acc = clean_for_window(v_acc_raw[csv_mask])
                    print(f"  csv 裁切後: {len(t_acc)} 筆, 時間範圍 0 ~ {t_acc[-1]:.2f} s")

                    dt_acc  = np.median(np.diff(t_acc[t_acc > 0][:100])) if len(t_acc) > 10 else 0.01
                    dt_xlsx = np.median(np.diff(t_s[:100]))
                    win_acc    = max(int(WINDOW_SIZE * dt_xlsx / dt_acc), 30)
                    stride_acc = max(int(STRIDE     * dt_xlsx / dt_acc),  5)
                    t_p, f_p = get_sliding_freq(t_acc, v_acc, win_acc, stride_acc)
                    if len(t_p) > 0:
                        plt.plot(t_p, f_p, 'k--', label="Input (Accel-CSV)", alpha=0.8, linewidth=2)
                    print(f"  CSV: {len(t_acc)} 筆, win={win_acc}, stride={stride_acc}")
        else:
            print(f"  zip 不存在，略過 CSV")

        # ── 3. 畫 xlsx 層位 ───────────────────────────────────
        colors = {"ya": "red", "yb": "orange", "yc": "green", "yd": "blue", "ye":"cyan"}
        for name, raw_val in target_layers.items():
            if raw_val is None: continue
            clean_sig = clean_for_window(raw_val)
            if len(clean_sig) > WINDOW_SIZE:
                sig_med = medfilt(clean_sig, kernel_size=5)
                tp, fp = get_sliding_freq(t_s, sig_med, WINDOW_SIZE, STRIDE)
                if len(tp) > 0:
                    print(f"  層位 {name}: 頻率範圍 = {fp.min():.3f} ~ {fp.max():.3f} Hz")
                    plt.plot(tp, fp, color=colors[name], label=f"Layer {name}", alpha=0.7)

        plt.title(f"Sliding Window Analysis: {file_id}")
        plt.xlabel("Time (s)")
        plt.ylabel("Frequency (Hz)")
        plt.grid(True, alpha=0.3)
        plt.legend(loc='upper right')
        plt.tight_layout()
        plt.savefig(f"Sliding_{file_id}.png", dpi=150)
        plt.close()

        dt_acc  = np.median(np.diff(t_acc[:100]))
        dt_xlsx = np.median(np.diff(t_s[:100]))
        window_sec_acc  = win_acc * dt_acc
        window_sec_xlsx = WINDOW_SIZE * dt_xlsx

        print(f"  xlsx 觸發後: {len(t_s)} 筆, 時間範圍 0 ~ {t_s[-1]:.2f} s")
        print(f"  csv  觸發後: {len(t_acc)} 筆, 時間範圍 0 ~ {t_acc[-1]:.2f} s")
        print(f"  dt_xlsx={dt_xlsx:.4f}s, dt_acc={dt_acc:.4f}s")
        print(f"  xlsx 窗口={WINDOW_SIZE}點 = {window_sec_xlsx:.2f}s")
        print(f"  csv  窗口={win_acc}點 = {window_sec_acc:.2f}s")

    except Exception as e:
        print(f"失敗 {file_id}: {e}")
# Out:
# 資料夾 E:\EarthScienceFair_Data\1 找到 10 個 xlsx 檔案
# 資料夾 E:\EarthScienceFair_Data\2 找到 16 個 xlsx 檔案
# 資料夾 E:\EarthScienceFair_Data\3 找到 6 個 xlsx 檔案
# 資料夾 E:\EarthScienceFair_Data\4 找到 3 個 xlsx 檔案
#
# 處理中: 1-G2-1
#   xlsx 有效行數: 710/2411 筆
#   xlsx 觸發點: index=50, t=1.8333
#   xlsx ya 絕對值: min=0.0678, max=0.1978, 中位數=0.1457
#   csv acc 絕對值: min=0.0135, max=21.0661, 中位數=0.2862
#   csv 觸發點: index=1116, t=11.2005
#   csv 裁切後: 2190 筆, 時間範圍 0 ~ 21.96 s
#   CSV: 2190 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.808 ~ 3.187 Hz
#   層位 yb: 頻率範圍 = 1.793 ~ 3.420 Hz
#   層位 yc: 頻率範圍 = 1.805 ~ 3.567 Hz
#   層位 yd: 頻率範圍 = 1.805 ~ 3.585 Hz
#   層位 ye: 頻率範圍 = 1.626 ~ 3.589 Hz
#   xlsx 觸發後: 660 筆, 時間範圍 0 ~ 21.97 s
#   csv  觸發後: 2190 筆, 時間範圍 0 ~ 21.96 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G2-2
#   xlsx 有效行數: 711/2292 筆
#   xlsx 觸發點: index=45, t=1.6667
#   xlsx ya 絕對值: min=0.0678, max=0.1978, 中位數=0.1456
#   csv acc 絕對值: min=0.0123, max=21.8256, 中位數=0.0855
#   csv 觸發點: index=1581, t=15.8648
#   csv 裁切後: 2210 筆, 時間範圍 0 ~ 22.17 s
#   CSV: 2210 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.628 ~ 3.187 Hz
#   層位 yb: 頻率範圍 = 1.631 ~ 3.420 Hz
#   層位 yc: 頻率範圍 = 1.636 ~ 3.567 Hz
#   層位 yd: 頻率範圍 = 1.627 ~ 3.585 Hz
#   層位 ye: 頻率範圍 = 1.626 ~ 3.589 Hz
#   xlsx 觸發後: 666 筆, 時間範圍 0 ~ 22.17 s
#   csv  觸發後: 2210 筆, 時間範圍 0 ~ 22.17 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G2-3
#   xlsx 有效行數: 663/2331 筆
#   xlsx 觸發點: index=41, t=1.3667
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0287, max=21.1555, 中位數=0.5317
#   csv 觸發點: index=835, t=8.3806
#   csv 裁切後: 2064 筆, 時間範圍 0 ~ 20.70 s
#   CSV: 2064 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.883 ~ 3.587 Hz
#   層位 yb: 頻率範圍 = 1.879 ~ 3.564 Hz
#   層位 yc: 頻率範圍 = 1.874 ~ 3.592 Hz
#   層位 yd: 頻率範圍 = 1.878 ~ 3.599 Hz
#   層位 ye: 頻率範圍 = 1.883 ~ 3.588 Hz
#   xlsx 觸發後: 622 筆, 時間範圍 0 ~ 20.70 s
#   csv  觸發後: 2064 筆, 時間範圍 0 ~ 20.70 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G2-4
#   xlsx 有效行數: 712/2505 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.4836, max=0.8768, 中位數=0.6595
#   csv acc 絕對值: min=0.0097, max=21.2882, 中位數=0.2798
#   csv 觸發點: index=959, t=9.6253
#   csv 裁切後: 2362 筆, 時間範圍 0 ~ 23.69 s
#   CSV: 2362 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.743 ~ 3.598 Hz
#   層位 yb: 頻率範圍 = 1.741 ~ 3.603 Hz
#   層位 yc: 頻率範圍 = 1.743 ~ 3.594 Hz
#   層位 yd: 頻率範圍 = 1.742 ~ 3.594 Hz
#   層位 ye: 頻率範圍 = 1.743 ~ 3.591 Hz
#   xlsx 觸發後: 712 筆, 時間範圍 0 ~ 23.70 s
#   csv  觸發後: 2362 筆, 時間範圍 0 ~ 23.69 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G2-5
#   xlsx 有效行數: 689/2347 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0446, max=0.1320, 中位數=0.0852
#   csv acc 絕對值: min=0.0398, max=21.2604, 中位數=0.5317
#   csv 觸發點: index=870, t=8.7307
#   csv 裁切後: 2286 筆, 時間範圍 0 ~ 22.93 s
#   CSV: 2286 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.890 ~ 3.628 Hz
#   層位 yb: 頻率範圍 = 1.892 ~ 3.568 Hz
#   層位 yc: 頻率範圍 = 1.885 ~ 3.619 Hz
#   層位 yd: 頻率範圍 = 1.894 ~ 3.620 Hz
#   層位 ye: 頻率範圍 = 1.897 ~ 3.625 Hz
#   xlsx 觸發後: 689 筆, 時間範圍 0 ~ 22.93 s
#   csv  觸發後: 2286 筆, 時間範圍 0 ~ 22.93 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-1
#   xlsx 有效行數: 749/2576 筆
#   xlsx 觸發點: index=47, t=1.5667
#   xlsx ya 絕對值: min=0.0906, max=0.1710, 中位數=0.1241
#   csv acc 絕對值: min=0.0157, max=21.3532, 中位數=0.8412
#   csv 觸發點: index=790, t=7.9272
#   csv 裁切後: 2329 筆, 時間範圍 0 ~ 23.36 s
#   CSV: 2329 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.796 ~ 3.714 Hz
#   層位 yb: 頻率範圍 = 1.792 ~ 3.697 Hz
#   層位 yc: 頻率範圍 = 1.783 ~ 3.690 Hz
#   層位 yd: 頻率範圍 = 1.777 ~ 3.743 Hz
#   層位 ye: 頻率範圍 = 1.783 ~ 3.740 Hz
#   xlsx 觸發後: 702 筆, 時間範圍 0 ~ 23.37 s
#   csv  觸發後: 2329 筆, 時間範圍 0 ~ 23.36 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-2
#   xlsx 有效行數: 786/2518 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.2303, max=0.6370, 中位數=0.4510
#   csv acc 絕對值: min=0.0213, max=21.4873, 中位數=0.3923
#   csv 觸發點: index=1128, t=11.3204
#   csv 裁切後: 2585 筆, 時間範圍 0 ~ 25.93 s
#   CSV: 2585 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.766 ~ 3.572 Hz
#   層位 yb: 頻率範圍 = 1.754 ~ 3.573 Hz
#   層位 yc: 頻率範圍 = 1.753 ~ 3.582 Hz
#   層位 yd: 頻率範圍 = 1.754 ~ 3.604 Hz
#   層位 ye: 頻率範圍 = 1.762 ~ 3.614 Hz
#   xlsx 觸發後: 786 筆, 時間範圍 0 ~ 26.17 s
#   csv  觸發後: 2585 筆, 時間範圍 0 ~ 25.93 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-3
#   xlsx 有效行數: 718/2677 筆
#   xlsx 觸發點: index=38, t=1.2667
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0389, max=21.2176, 中位數=0.7189
#   csv 觸發點: index=935, t=9.3820
#   csv 裁切後: 2256 筆, 時間範圍 0 ~ 22.63 s
#   CSV: 2256 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.778 ~ 3.659 Hz
#   層位 yb: 頻率範圍 = 1.776 ~ 3.648 Hz
#   層位 yc: 頻率範圍 = 1.769 ~ 3.647 Hz
#   層位 yd: 頻率範圍 = 1.768 ~ 3.663 Hz
#   層位 ye: 頻率範圍 = 1.768 ~ 3.665 Hz
#   xlsx 觸發後: 680 筆, 時間範圍 0 ~ 22.64 s
#   csv  觸發後: 2256 筆, 時間範圍 0 ~ 22.63 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-4
#   xlsx 有效行數: 744/2355 筆
#   xlsx 觸發點: index=56, t=1.8667
#   xlsx ya 絕對值: min=0.1025, max=0.1838, 中位數=0.1324
#   csv acc 絕對值: min=0.0086, max=21.1313, 中位數=0.8405
#   csv 觸發點: index=751, t=7.5377
#   csv 裁切後: 2283 筆, 時間範圍 0 ~ 22.90 s
#   CSV: 2283 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.873 ~ 3.642 Hz
#   層位 yb: 頻率範圍 = 1.874 ~ 3.629 Hz
#   層位 yc: 頻率範圍 = 1.870 ~ 3.634 Hz
#   層位 yd: 頻率範圍 = 1.863 ~ 3.636 Hz
#   層位 ye: 頻率範圍 = 1.869 ~ 3.667 Hz
#   xlsx 觸發後: 688 筆, 時間範圍 0 ~ 22.90 s
#   csv  觸發後: 2283 筆, 時間範圍 0 ~ 22.90 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 1-G3-5
#   xlsx 有效行數: 681/2396 筆
#   xlsx 觸發點: index=20, t=0.6667
#   xlsx ya 絕對值: min=0.0996, max=0.1791, 中位數=0.1357
#   csv acc 絕對值: min=0.0348, max=21.3678, 中位數=0.3534
#   csv 觸發點: index=1152, t=11.5583
#   csv 裁切後: 2193 筆, 時間範圍 0 ~ 22.00 s
#   CSV: 2193 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.928 ~ 3.596 Hz
#   層位 yb: 頻率範圍 = 1.930 ~ 3.579 Hz
#   層位 yc: 頻率範圍 = 1.916 ~ 3.585 Hz
#   層位 yd: 頻率範圍 = 1.920 ~ 3.577 Hz
#   層位 ye: 頻率範圍 = 1.928 ~ 3.588 Hz
#   xlsx 觸發後: 661 筆, 時間範圍 0 ~ 22.00 s
#   csv  觸發後: 2193 筆, 時間範圍 0 ~ 22.00 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-1
#   xlsx 有效行數: 757/2773 筆
#   xlsx 觸發點: index=51, t=1.7000
#   xlsx ya 絕對值: min=0.0761, max=0.1957, 中位數=0.1182
#   csv acc 絕對值: min=0.0468, max=20.8883, 中位數=0.4662
#   csv 觸發點: index=1151, t=11.5645
#   csv 裁切後: 2342 筆, 時間範圍 0 ~ 23.49 s
#   CSV: 2342 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.697 ~ 3.737 Hz
#   層位 yb: 頻率範圍 = 1.676 ~ 3.734 Hz
#   層位 yc: 頻率範圍 = 1.676 ~ 3.768 Hz
#   層位 yd: 頻率範圍 = 1.676 ~ 3.774 Hz
#   層位 ye: 頻率範圍 = 1.679 ~ 3.773 Hz
#   xlsx 觸發後: 706 筆, 時間範圍 0 ~ 23.50 s
#   csv  觸發後: 2342 筆, 時間範圍 0 ~ 23.49 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-2
#   xlsx 有效行數: 747/2699 筆
#   xlsx 觸發點: index=375, t=12.5017
#   xlsx ya 絕對值: min=0.0455, max=0.1707, 中位數=0.0820
#   csv acc 絕對值: min=0.0346, max=20.6518, 中位數=0.9420
#   csv 觸發點: index=744, t=7.4733
#   csv 裁切後: 1233 筆, 時間範圍 0 ~ 12.36 s
#   CSV: 1233 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.843 ~ 3.279 Hz
#   層位 yb: 頻率範圍 = 1.837 ~ 3.264 Hz
#   層位 yc: 頻率範圍 = 1.812 ~ 3.246 Hz
#   層位 yd: 頻率範圍 = 1.830 ~ 3.232 Hz
#   層位 ye: 頻率範圍 = 1.845 ~ 3.233 Hz
#   xlsx 觸發後: 372 筆, 時間範圍 0 ~ 12.37 s
#   csv  觸發後: 1233 筆, 時間範圍 0 ~ 12.36 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-3
#   xlsx 有效行數: 668/2333 筆
#   xlsx 觸發點: index=33, t=1.1000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0230, max=20.8028, 中位數=0.6852
#   csv 觸發點: index=744, t=7.4676
#   csv 裁切後: 2107 筆, 時間範圍 0 ~ 21.13 s
#   CSV: 2107 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.927 ~ 3.577 Hz
#   層位 yb: 頻率範圍 = 1.926 ~ 3.597 Hz
#   層位 yc: 頻率範圍 = 1.918 ~ 3.591 Hz
#   層位 yd: 頻率範圍 = 1.902 ~ 3.605 Hz
#   層位 ye: 頻率範圍 = 1.922 ~ 3.611 Hz
#   xlsx 觸發後: 635 筆, 時間範圍 0 ~ 21.13 s
#   csv  觸發後: 2107 筆, 時間範圍 0 ~ 21.13 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-4
#   xlsx 有效行數: 738/2460 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0316, max=20.8141, 中位數=0.6934
#   csv 觸發點: index=890, t=8.9315
#   csv 裁切後: 2449 筆, 時間範圍 0 ~ 24.57 s
#   CSV: 2449 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.705 ~ 3.685 Hz
#   層位 yb: 頻率範圍 = 1.755 ~ 3.685 Hz
#   層位 yc: 頻率範圍 = 1.757 ~ 3.701 Hz
#   層位 yd: 頻率範圍 = 1.706 ~ 3.721 Hz
#   層位 ye: 頻率範圍 = 1.751 ~ 3.743 Hz
#   xlsx 觸發後: 738 筆, 時間範圍 0 ~ 24.57 s
#   csv  觸發後: 2449 筆, 時間範圍 0 ~ 24.57 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G1-5
#   xlsx 有效行數: 718/2510 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0288, max=20.7179, 中位數=0.4382
#   csv 觸發點: index=963, t=9.6677
#   csv 裁切後: 2382 筆, 時間範圍 0 ~ 23.89 s
#   CSV: 2382 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.698 ~ 3.615 Hz
#   層位 yb: 頻率範圍 = 1.705 ~ 3.648 Hz
#   層位 yc: 頻率範圍 = 1.707 ~ 3.537 Hz
#   層位 yd: 頻率範圍 = 1.701 ~ 3.691 Hz
#   層位 ye: 頻率範圍 = 1.698 ~ 3.703 Hz
#   xlsx 觸發後: 718 筆, 時間範圍 0 ~ 23.90 s
#   csv  觸發後: 2382 筆, 時間範圍 0 ~ 23.89 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G2-1
#   xlsx 有效行數: 557/2049 筆
#   xlsx 觸發點: index=35, t=1.1667
#   xlsx ya 絕對值: min=0.0983, max=0.1733, 中位數=0.1308
#   csv acc 絕對值: min=0.0334, max=11.4331, 中位數=0.2729
#   csv 觸發點: index=775, t=7.7786
#   csv 裁切後: 1731 筆, 時間範圍 0 ~ 17.36 s
#   CSV: 1731 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.903 ~ 2.873 Hz
#   層位 yb: 頻率範圍 = 1.897 ~ 2.872 Hz
#   層位 yc: 頻率範圍 = 1.892 ~ 2.872 Hz
#   層位 yd: 頻率範圍 = 1.886 ~ 2.870 Hz
#   層位 ye: 頻率範圍 = 1.885 ~ 2.866 Hz
#   xlsx 觸發後: 522 筆, 時間範圍 0 ~ 17.37 s
#   csv  觸發後: 1731 筆, 時間範圍 0 ~ 17.36 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G2-2
#   xlsx 有效行數: 522/1839 筆
#   xlsx 觸發點: index=222, t=7.4000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0299, max=11.6232, 中位數=0.2373
#   csv 觸發點: index=759, t=7.6162
#   csv 裁切後: 994 筆, 時間範圍 0 ~ 9.97 s
#   CSV: 994 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.840 ~ 2.580 Hz
#   層位 yb: 頻率範圍 = 1.842 ~ 2.581 Hz
#   層位 yc: 頻率範圍 = 1.836 ~ 2.574 Hz
#   層位 yd: 頻率範圍 = 1.836 ~ 2.575 Hz
#   層位 ye: 頻率範圍 = 1.833 ~ 2.576 Hz
#   xlsx 觸發後: 300 筆, 時間範圍 0 ~ 9.97 s
#   csv  觸發後: 994 筆, 時間範圍 0 ~ 9.97 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G2-3
#   xlsx 有效行數: 579/2016 筆
#   xlsx 觸發點: index=58, t=1.9333
#   xlsx ya 絕對值: min=0.0913, max=0.1676, 中位數=0.1222
#   csv acc 絕對值: min=0.0395, max=11.2750, 中位數=0.1963
#   csv 觸發點: index=968, t=9.7108
#   csv 裁切後: 1728 筆, 時間範圍 0 ~ 17.33 s
#   CSV: 1728 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.921 ~ 2.868 Hz
#   層位 yb: 頻率範圍 = 1.917 ~ 2.869 Hz
#   層位 yc: 頻率範圍 = 1.911 ~ 2.871 Hz
#   層位 yd: 頻率範圍 = 1.914 ~ 2.865 Hz
#   層位 ye: 頻率範圍 = 1.925 ~ 2.868 Hz
#   xlsx 觸發後: 521 筆, 時間範圍 0 ~ 17.33 s
#   csv  觸發後: 1728 筆, 時間範圍 0 ~ 17.33 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G3-1
#   xlsx 有效行數: 654/2218 筆
#   xlsx 觸發點: index=37, t=1.2333
#   xlsx ya 絕對值: min=0.0754, max=0.1585, 中位數=0.1158
#   csv acc 絕對值: min=0.0262, max=13.5200, 中位數=0.4512
#   csv 觸發點: index=830, t=8.3322
#   csv 裁切後: 2047 筆, 時間範圍 0 ~ 20.53 s
#   CSV: 2047 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.762 ~ 3.080 Hz
#   層位 yb: 頻率範圍 = 1.755 ~ 3.066 Hz
#   層位 yc: 頻率範圍 = 1.744 ~ 3.064 Hz
#   層位 yd: 頻率範圍 = 1.741 ~ 3.052 Hz
#   層位 ye: 頻率範圍 = 1.738 ~ 3.058 Hz
#   xlsx 觸發後: 617 筆, 時間範圍 0 ~ 20.53 s
#   csv  觸發後: 2047 筆, 時間範圍 0 ~ 20.53 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G3-2
#   xlsx 有效行數: 343/1410 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0538, max=0.1374, 中位數=0.0964
#   csv acc 絕對值: min=0.0290, max=13.9887, 中位數=0.3758
#   csv 觸發點: index=733, t=7.3551
#   csv 裁切後: 1136 筆, 時間範圍 0 ~ 11.39 s
#   CSV: 1136 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.944 ~ 2.945 Hz
#   層位 yb: 頻率範圍 = 1.935 ~ 2.966 Hz
#   層位 yc: 頻率範圍 = 1.930 ~ 2.930 Hz
#   層位 yd: 頻率範圍 = 1.926 ~ 2.956 Hz
#   層位 ye: 頻率範圍 = 1.924 ~ 2.960 Hz
#   xlsx 觸發後: 343 筆, 時間範圍 0 ~ 11.40 s
#   csv  觸發後: 1136 筆, 時間範圍 0 ~ 11.39 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G3-3
#   xlsx 有效行數: 621/622 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0435, max=0.1249, 中位數=0.0843
#   csv acc 絕對值: min=0.0400, max=13.3901, 中位數=0.5864
#   csv 觸發點: index=888, t=8.9144
#   csv 裁切後: 2060 筆, 時間範圍 0 ~ 20.66 s
#   CSV: 2060 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.893 ~ 3.043 Hz
#   層位 yb: 頻率範圍 = 1.890 ~ 3.046 Hz
#   層位 yc: 頻率範圍 = 1.881 ~ 3.059 Hz
#   層位 yd: 頻率範圍 = 1.882 ~ 3.052 Hz
#   層位 ye: 頻率範圍 = 1.879 ~ 3.056 Hz
#   xlsx 觸發後: 621 筆, 時間範圍 0 ~ 20.67 s
#   csv  觸發後: 2060 筆, 時間範圍 0 ~ 20.66 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G4-1
#   xlsx 有效行數: 233/961 筆
#   xlsx 觸發點: index=44, t=1.4667
#   xlsx ya 絕對值: min=0.0883, max=0.1627, 中位數=0.1115
#   csv acc 絕對值: min=0.0393, max=21.3812, 中位數=0.3046
#   csv 觸發點: index=618, t=6.2017
#   csv 裁切後: 625 筆, 時間範圍 0 ~ 6.26 s
#   CSV: 625 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 2.153 ~ 2.456 Hz
#   層位 yb: 頻率範圍 = 2.155 ~ 2.446 Hz
#   層位 yc: 頻率範圍 = 2.157 ~ 2.441 Hz
#   層位 yd: 頻率範圍 = 2.152 ~ 2.434 Hz
#   層位 ye: 頻率範圍 = 2.151 ~ 2.421 Hz
#   xlsx 觸發後: 189 筆, 時間範圍 0 ~ 6.27 s
#   csv  觸發後: 625 筆, 時間範圍 0 ~ 6.26 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G4-2
# 失敗 2-G4-2: 't_s'
#
# 處理中: 2-G4-3
#   xlsx 有效行數: 278/869 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0414, max=0.1238, 中位數=0.0839
#   csv acc 絕對值: min=0.0286, max=21.4542, 中位數=0.3415
#   csv 觸發點: index=958, t=9.6133
#   csv 裁切後: 921 筆, 時間範圍 0 ~ 9.23 s
#   CSV: 921 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.885 ~ 2.797 Hz
#   層位 yb: 頻率範圍 = 1.871 ~ 2.776 Hz
#   層位 yc: 頻率範圍 = 1.883 ~ 2.767 Hz
#   層位 yd: 頻率範圍 = 1.882 ~ 2.764 Hz
#   層位 ye: 頻率範圍 = 1.892 ~ 2.764 Hz
#   xlsx 觸發後: 278 筆, 時間範圍 0 ~ 9.23 s
#   csv  觸發後: 921 筆, 時間範圍 0 ~ 9.23 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G5-1
#   xlsx 有效行數: 302/1179 筆
#   xlsx 觸發點: index=35, t=1.1667
#   xlsx ya 絕對值: min=0.0984, max=0.1842, 中位數=0.1343
#   csv acc 絕對值: min=0.0327, max=17.3296, 中位數=1.0479
#   csv 觸發點: index=938, t=9.4133
#   csv 裁切後: 884 筆, 時間範圍 0 ~ 8.86 s
#   CSV: 884 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 2.041 ~ 2.869 Hz
#   層位 yb: 頻率範圍 = 2.038 ~ 2.857 Hz
#   層位 yc: 頻率範圍 = 2.045 ~ 2.869 Hz
#   層位 yd: 頻率範圍 = 2.033 ~ 2.819 Hz
#   層位 ye: 頻率範圍 = 2.030 ~ 2.818 Hz
#   xlsx 觸發後: 267 筆, 時間範圍 0 ~ 8.87 s
#   csv  觸發後: 884 筆, 時間範圍 0 ~ 8.86 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 2-G5-2
#   xlsx 有效行數: 239/1012 筆
#   xlsx 觸發點: index=13, t=0.4333
#   xlsx ya 絕對值: min=0.0933, max=0.1819, 中位數=0.1368
#   csv acc 絕對值: min=0.0128, max=15.9136, 中位數=0.3173
#   csv 觸發點: index=1111, t=11.1518
#   csv 裁切後: 748 筆, 時間範圍 0 ~ 7.50 s
#   CSV: 748 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 2.191 ~ 2.594 Hz
#   層位 yb: 頻率範圍 = 2.186 ~ 2.619 Hz
#   層位 yc: 頻率範圍 = 2.180 ~ 2.645 Hz
#   層位 yd: 頻率範圍 = 2.177 ~ 2.658 Hz
#   層位 ye: 頻率範圍 = 2.169 ~ 2.656 Hz
#   xlsx 觸發後: 226 筆, 時間範圍 0 ~ 7.50 s
#   csv  觸發後: 748 筆, 時間範圍 0 ~ 7.50 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G1-1
#   xlsx 有效行數: 682/2219 筆
#   xlsx 觸發點: index=53, t=1.7667
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0219, max=20.9714, 中位數=0.2637
#   csv 觸發點: index=1162, t=11.6612
#   csv 裁切後: 2087 筆, 時間範圍 0 ~ 20.93 s
#   CSV: 2087 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.671 ~ 3.586 Hz
#   層位 yb: 頻率範圍 = 1.671 ~ 3.291 Hz
#   層位 yc: 頻率範圍 = 1.671 ~ 3.603 Hz
#   層位 yd: 頻率範圍 = 1.672 ~ 3.583 Hz
#   層位 ye: 頻率範圍 = 1.665 ~ 3.611 Hz
#   xlsx 觸發後: 629 筆, 時間範圍 0 ~ 20.94 s
#   csv  觸發後: 2087 筆, 時間範圍 0 ~ 20.93 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G1-2
#   xlsx 有效行數: 671/1364 筆
#   xlsx 觸發點: index=42, t=1.4000
#   xlsx ya 絕對值: min=0.1041, max=0.1908, 中位數=0.1374
#   csv acc 絕對值: min=0.0263, max=20.9491, 中位數=0.2682
#   csv 觸發點: index=1042, t=10.4542
#   csv 裁切後: 2087 筆, 時間範圍 0 ~ 20.93 s
#   CSV: 2087 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.773 ~ 3.588 Hz
#   層位 yb: 頻率範圍 = 1.791 ~ 3.345 Hz
#   層位 yc: 頻率範圍 = 1.764 ~ 3.557 Hz
#   層位 yd: 頻率範圍 = 1.774 ~ 3.565 Hz
#   層位 ye: 頻率範圍 = 1.770 ~ 3.564 Hz
#   xlsx 觸發後: 629 筆, 時間範圍 0 ~ 20.94 s
#   csv  觸發後: 2087 筆, 時間範圍 0 ~ 20.93 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G1-3
#   xlsx 有效行數: 622/622 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0312, max=21.1846, 中位數=0.4647
#   csv 觸發點: index=1022, t=10.2567
#   csv 裁切後: 2063 筆, 時間範圍 0 ~ 20.69 s
#   CSV: 2063 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.893 ~ 3.043 Hz
#   層位 yb: 頻率範圍 = 1.890 ~ 3.046 Hz
#   層位 yc: 頻率範圍 = 1.881 ~ 3.059 Hz
#   層位 yd: 頻率範圍 = 1.882 ~ 3.052 Hz
#   層位 ye: 頻率範圍 = 1.879 ~ 3.056 Hz
#   xlsx 觸發後: 622 筆, 時間範圍 0 ~ 20.70 s
#   csv  觸發後: 2063 筆, 時間範圍 0 ~ 20.69 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G2-1
#   xlsx 有效行數: 605/2218 筆
#   xlsx 觸發點: index=282, t=9.4000
#   xlsx ya 絕對值: min=0.0706, max=0.1416, 中位數=0.1101
#   csv acc 絕對值: min=0.0367, max=13.0846, 中位數=0.2583
#   csv 觸發點: index=709, t=7.1147
#   csv 裁切後: 1070 筆, 時間範圍 0 ~ 10.73 s
#   CSV: 1070 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.817 ~ 2.840 Hz
#   層位 yb: 頻率範圍 = 1.816 ~ 2.841 Hz
#   層位 yc: 頻率範圍 = 1.808 ~ 2.836 Hz
#   層位 yd: 頻率範圍 = 1.815 ~ 2.841 Hz
#   層位 ye: 頻率範圍 = 1.825 ~ 2.835 Hz
#   xlsx 觸發後: 323 筆, 時間範圍 0 ~ 10.74 s
#   csv  觸發後: 1070 筆, 時間範圍 0 ~ 10.73 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G2-2
#   xlsx 有效行數: 347/1375 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0262, max=13.0446, 中位數=0.2982
#   csv 觸發點: index=858, t=8.6108
#   csv 裁切後: 1150 筆, 時間範圍 0 ~ 11.53 s
#   CSV: 1150 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.944 ~ 3.080 Hz
#   層位 yb: 頻率範圍 = 1.935 ~ 3.053 Hz
#   層位 yc: 頻率範圍 = 1.920 ~ 3.096 Hz
#   層位 yd: 頻率範圍 = 1.926 ~ 3.013 Hz
#   層位 ye: 頻率範圍 = 1.924 ~ 3.000 Hz
#   xlsx 觸發後: 347 筆, 時間範圍 0 ~ 11.53 s
#   csv  觸發後: 1150 筆, 時間範圍 0 ~ 11.53 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 3-G2-3
#   xlsx 有效行數: 622/622 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0435, max=0.1249, 中位數=0.0844
#   csv acc 絕對值: min=0.0437, max=13.1936, 中位數=0.2099
#   csv 觸發點: index=878, t=8.8115
#   csv 裁切後: 2063 筆, 時間範圍 0 ~ 20.69 s
#   CSV: 2063 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.893 ~ 3.043 Hz
#   層位 yb: 頻率範圍 = 1.890 ~ 3.046 Hz
#   層位 yc: 頻率範圍 = 1.881 ~ 3.059 Hz
#   層位 yd: 頻率範圍 = 1.882 ~ 3.052 Hz
#   層位 ye: 頻率範圍 = 1.879 ~ 3.056 Hz
#   xlsx 觸發後: 622 筆, 時間範圍 0 ~ 20.70 s
#   csv  觸發後: 2063 筆, 時間範圍 0 ~ 20.69 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 4-G1-1
#   xlsx 有效行數: 775/2508 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0682, max=0.1370, 中位數=0.1027
#   csv acc 絕對值: min=0.0355, max=21.4478, 中位數=0.6284
#   csv 觸發點: index=1070, t=10.7545
#   csv 裁切後: 2572 筆, 時間範圍 0 ~ 25.80 s
#   CSV: 2572 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.781 ~ 3.752 Hz
#   層位 yb: 頻率範圍 = 1.786 ~ 3.767 Hz
#   層位 yc: 頻率範圍 = 1.782 ~ 3.762 Hz
#   層位 yd: 頻率範圍 = 1.784 ~ 3.765 Hz
#   層位 ye: 頻率範圍 = 1.784 ~ 3.753 Hz
#   xlsx 觸發後: 775 筆, 時間範圍 0 ~ 25.80 s
#   csv  觸發後: 2572 筆, 時間範圍 0 ~ 25.80 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 4-G1-2
#   xlsx 有效行數: 681/2364 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=0.0508, max=0.1207, 中位數=0.0817
#   csv acc 絕對值: min=0.0178, max=21.7388, 中位數=0.3794
#   csv 觸發點: index=1000, t=10.0352
#   csv 裁切後: 2259 筆, 時間範圍 0 ~ 22.66 s
#   CSV: 2259 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.783 ~ 3.614 Hz
#   層位 yb: 頻率範圍 = 1.784 ~ 3.614 Hz
#   層位 yc: 頻率範圍 = 1.779 ~ 3.619 Hz
#   層位 yd: 頻率範圍 = 1.779 ~ 3.609 Hz
#   層位 ye: 頻率範圍 = 1.779 ~ 3.610 Hz
#   xlsx 觸發後: 681 筆, 時間範圍 0 ~ 22.67 s
#   csv  觸發後: 2259 筆, 時間範圍 0 ~ 22.66 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
#
# 處理中: 4-G1-3
#   xlsx 有效行數: 776/2684 筆
#   xlsx 觸發點: index=0, t=0.0000
#   xlsx ya 絕對值: min=nan, max=nan, 中位數=nan
#   csv acc 絕對值: min=0.0189, max=21.5910, 中位數=0.7038
#   csv 觸發點: index=880, t=8.8333
#   csv 裁切後: 2575 筆, 時間範圍 0 ~ 25.83 s
#   CSV: 2575 筆, win=498, stride=16
#   層位 ya: 頻率範圍 = 1.731 ~ 3.740 Hz
#   層位 yb: 頻率範圍 = 1.727 ~ 3.737 Hz
#   層位 yc: 頻率範圍 = 1.723 ~ 3.739 Hz
#   層位 yd: 頻率範圍 = 1.718 ~ 3.740 Hz
#   層位 ye: 頻率範圍 = 1.731 ~ 3.728 Hz
#   xlsx 觸發後: 776 筆, 時間範圍 0 ~ 25.84 s
#   csv  觸發後: 2575 筆, 時間範圍 0 ~ 25.83 s
#   dt_xlsx=0.0333s, dt_acc=0.0100s
#   xlsx 窗口=150點 = 5.00s
#   csv  窗口=498點 = 5.00s
